# %% [markdown]
# # Intro to Pandas

# %% [markdown]
# We start by making the usual imports with their usual aliases: `numpy`, `matplotlib.pyplot`, and `pandas`

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Loading Data

# %% [markdown]
# Here we use `pd.read_csv` to load the data from a URL (local file paths work as well), into a pandas `DataFrame`:

# %%
pokedex = pd.read_csv('https://raw.githubusercontent.com/lgreski/pokemonData/master/Pokemon.csv')

# %% [markdown]
# ## Previewing Data

# %% [markdown]
# The `.head(n)` method of a `DataFrame` object returns a `DataFrame` containing the first `n` rows of the source. If no `n` is passed, the method returns the first 5 rows by default.

# %%
pokedex.head()
# Out:
#    ID        Name Form  Type1   Type2  Total  HP  Attack  Defense  Sp. Atk
# 0   1   Bulbasaur       Grass  Poison    318  45      49       49       65  \
# 1   2     Ivysaur       Grass  Poison    405  60      62       63       80
# 2   3    Venusaur       Grass  Poison    525  80      82       83      100
# 3   4  Charmander        Fire            309  39      52       43       60
# 4   5  Charmeleon        Fire            405  58      64       58       80
#
#    Sp. Def  Speed  Generation
# 0       65     45           1
# 1       80     60           1
# 2      100     80           1
# 3       50     65           1
# 4       65     80           1

# %% [markdown]
# Similar to the `.head()` method, the `.tail(n)` method returns the *last* `n` rows of the dataset.

# %%
pokedex.tail()
# Out:
#         ID          Name Form     Type1     Type2  Total   HP  Attack
# 1189  1006  Iron Valiant          Fairy  Fighting    590   74     130  \
# 1190  1007      Koraidon       Fighting    Dragon    670  100     135
# 1191  1008      Miraidon       Electric    Dragon    670  100      85
# 1192  1009  Walking Wake          Water    Dragon    590   99      83
# 1193  1010   Iron Leaves          Grass   Psychic    590   90     130
#
#       Defense  Sp. Atk  Sp. Def  Speed  Generation
# 1189       90      120       60    116           9
# 1190      115       85      100    135           9
# 1191      100      135      115    135           9
# 1192       91      125       83    109           9
# 1193       88       70      108    104           9

# %% [markdown]
# Just as the `.head()` and `.tail()` `DataFrame` methods return subsets of the dataset, so does `.sample(n)`. In this case, we get `n` rows of data sampled *randomly* from the dataset.

# %%
# Each time you run this cell you'll get DIFFERENT values
pokedex.sample(10)
# Out:
#         ID       Name Form     Type1   Type2  Total   HP  Attack  Defense
# 1117   939  Bellibolt       Electric            495  109      64       91  \
# 1134   956   Espathra        Psychic            481   95      60       60
# 323    324    Torkoal           Fire            470   70      85      140
# 580    562     Yamask          Ghost            303   38      30       85
# 299    300     Skitty         Normal            260   50      45       45
# 1185  1002  Chien-Pao           Dark     Ice    570   80     120       80
# 403    398  Staraptor         Normal  Flying    485   85     120       70
# 330    331     Cacnea          Grass            335   50      85       40
# 542    526   Gigalith           Rock            515   85     135      130
# 41      42     Golbat         Poison  Flying    455   75      80       70
#
#       Sp. Atk  Sp. Def  Speed  Generation
# 1117      103       83     45           9
# 1134      101       60    105           9
# 323        85       70     20           3
# 580        55       65     30           5
# 299        35       35     50           3
# 1185       90       65    135           9
# 403        50       60    100           4
# 330        85       40     35           3
# 542        60       80     25           5
# 41         65       75     90           1

# %% [markdown]
#  If you'd like your random sample to be reproducible by others, you can also pass the `random_state` keyword argument with an integer seed for the random number generator as follows:

# %%
# Each time you run this cell you'll get the SAME values
pokedex.sample(10, random_state=123)
# Out:
#        ID        Name Form   Type1     Type2  Total   HP  Attack  Defense
# 156   157  Typhlosion         Fire              534   78      84       78  \
# 528   512    Simisage        Grass              498   75      98       63
# 854   744    Rockruff         Rock              280   45      65       40
# 893   778     Mimikyu        Ghost     Fairy    476   55      90       80
# 35     36    Clefable        Fairy              483   95      70       73
# 664   644      Zekrom       Dragon  Electric    680  100     150      120
# 1000  843   Silicobra       Ground              315   52      57       75
# 912   797  Celesteela        Steel    Flying    570   97     101      103
# 1146  967    Cyclizar       Dragon    Normal    501   70      95       65
# 453   444      Gabite       Dragon    Ground    410   68      90       65
#
#       Sp. Atk  Sp. Def  Speed  Generation
# 156       109       85    100           2
# 528        98       63    101           5
# 854        30       40     60           7
# 893        50      105     96           7
# 35         95       90     60           1
# 664       120      100     90           5
# 1000       35       50     46           8
# 912       107      101     61           7
# 1146       85       65    121           9
# 453        50       55     82           4

# %% [markdown]
# ## Summarizing Data

# %% [markdown]
# Pandas `DataFrame` objects have a few methods and attributes that yield summary information.

# %% [markdown]
# `.info()` gives us a summary that includes the number of rows, the names and data types of the columns, and the number of non-null entries in each column.

# %%
pokedex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1194 entries, 0 to 1193
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          1194 non-null   int64
#  1   Name        1194 non-null   object
#  2   Form        1194 non-null   object
#  3   Type1       1194 non-null   object
#  4   Type2       1194 non-null   object
#  5   Total       1194 non-null   int64
#  6   HP          1194 non-null   int64
#  7   Attack      1194 non-null   int64
#  8   Defense     1194 non-null   int64
#  9   Sp. Atk     1194 non-null   int64
#  10  Sp. Def     1194 non-null   int64
#  11  Speed       1194 non-null   int64
#  12  Generation  1194 non-null   int64
# dtypes: int64(9), object(4)
# memory usage: 121.4+ KB

# %% [markdown]
# The `.describe()` method gives us a *statistical* view of the data, including a count, mean, standard deviation, minimum, quartiles, and maximum of each column.

# %%
pokedex.describe()
# Out:
#                 ID        Total           HP       Attack      Defense
# count  1194.000000  1194.000000  1194.000000  1194.000000  1194.000000  \
# mean    492.746231   441.206868    70.887772    80.948911    74.587102
# std     293.719541   121.015326    26.859651    32.122250    30.678626
# min       1.000000   175.000000     1.000000     5.000000     5.000000
# 25%     235.250000   330.000000    52.000000    56.000000    51.250000
# 50%     486.500000   460.500000    70.000000    80.000000    70.000000
# 75%     741.750000   520.000000    85.000000   100.000000    90.000000
# max    1010.000000  1125.000000   255.000000   190.000000   250.000000
#
#            Sp. Atk      Sp. Def        Speed   Generation
# count  1194.000000  1194.000000  1194.000000  1194.000000
# mean     72.876884    72.128141    69.778057     4.989950
# std      32.696051    27.628468    30.195593     2.564161
# min      10.000000    20.000000     5.000000     1.000000
# 25%      50.000000    50.000000    45.000000     3.000000
# 50%      65.000000    70.000000    67.500000     5.000000
# 75%      95.000000    90.000000    90.750000     7.000000
# max     194.000000   250.000000   200.000000     9.000000

# %% [markdown]
# The `.shape` attribute of a `DataFrame` gives us the *shape* of the data - the number of rows and columns.

# %%
pokedex.shape
# Out:
# (1194, 13)

# %% [markdown]
# The `.size` attribute gives us the total number of values in the dataset:

# %%
pokedex.size
# Out:
# 15522

# %% [markdown]
# ## Slicing and Filtering Data

# %% [markdown]
# ### Simple Slices

# %% [markdown]
# Similar to python `list` objects, we can use *slicing* to get subsets of our data. For example, I can get the first 20 rows of our data as follows:

# %%
pokedex[:20]
# Out:
#     ID        Name Form   Type1   Type2  Total  HP  Attack  Defense  Sp. Atk
# 0    1   Bulbasaur        Grass  Poison    318  45      49       49       65  \
# 1    2     Ivysaur        Grass  Poison    405  60      62       63       80
# 2    3    Venusaur        Grass  Poison    525  80      82       83      100
# 3    4  Charmander         Fire            309  39      52       43       60
# 4    5  Charmeleon         Fire            405  58      64       58       80
# 5    6   Charizard         Fire  Flying    534  78      84       78      109
# 6    7    Squirtle        Water            314  44      48       65       50
# 7    8   Wartortle        Water            405  59      63       80       65
# 8    9   Blastoise        Water            530  79      83      100       85
# 9   10    Caterpie          Bug            195  45      30       35       20
# 10  11     Metapod          Bug            205  50      20       55       25
# 11  12  Butterfree          Bug  Flying    395  60      45       50       90
# 12  13      Weedle          Bug  Poison    195  40      35       30       20
# 13  14      Kakuna          Bug  Poison    205  45      25       50       25
# 14  15    Beedrill          Bug  Poison    395  65      90       40       45
# 15  16      Pidgey       Normal  Flying    251  40      45       40       35
# 16  17   Pidgeotto       Normal  Flying    349  63      60       55       50
# 17  18     Pidgeot       Normal  Flying    479  83      80       75       70
# 18  19     Rattata       Normal            253  30      56       35       25
# 19  20    Raticate       Normal            413  55      81       60       50
#
#     Sp. Def  Speed  Generation
# 0        65     45           1
# 1        80     60           1
# 2       100     80           1
# 3        50     65           1
# 4        65     80           1
# 5        85    100           1
# 6        64     43           1
# 7        80     58           1
# 8       105     78           1
# 9        20     45           1
# 10       25     30           1
# 11       80     70           1
# 12       20     50           1
# 13       25     35           1
# 14       80     75           1
# 15       35     56           1
# 16       50     71           1
# 17       70    101           1
# 18       35     72           1
# 19       70     97           1

# %% [markdown]
# We can similarly slice by column as well, only this time we use column *names*. In this case let's just take the `Name` and `Total` columns:

# %%
# Note that since we're passing multiple columns, they need to be in a list!
pokedex[['Name', 'Total']]
# Out:
#               Name  Total
# 0        Bulbasaur    318
# 1          Ivysaur    405
# 2         Venusaur    525
# 3       Charmander    309
# 4       Charmeleon    405
# ...            ...    ...
# 1189  Iron Valiant    590
# 1190      Koraidon    670
# 1191      Miraidon    670
# 1192  Walking Wake    590
# 1193   Iron Leaves    590
#
# [1194 rows x 2 columns]

# %% [markdown]
# Though this is less common, we can slice by row and column *indexes* using the `.iloc` method as follows:

# %%
# Combines the previous two examples 
# the first 20 pokemon with just the second and sixth columns
# using .iloc
pokedex.iloc[:20, [1, 5]]
# Out:
#           Name  Total
# 0    Bulbasaur    318
# 1      Ivysaur    405
# 2     Venusaur    525
# 3   Charmander    309
# 4   Charmeleon    405
# 5    Charizard    534
# 6     Squirtle    314
# 7    Wartortle    405
# 8    Blastoise    530
# 9     Caterpie    195
# 10     Metapod    205
# 11  Butterfree    395
# 12      Weedle    195
# 13      Kakuna    205
# 14    Beedrill    395
# 15      Pidgey    251
# 16   Pidgeotto    349
# 17     Pidgeot    479
# 18     Rattata    253
# 19    Raticate    413

# %% [markdown]
# Equivalently, we might try:

# %%
pokedex[:20][['Name', 'Total']]
# Out:
#           Name  Total
# 0    Bulbasaur    318
# 1      Ivysaur    405
# 2     Venusaur    525
# 3   Charmander    309
# 4   Charmeleon    405
# 5    Charizard    534
# 6     Squirtle    314
# 7    Wartortle    405
# 8    Blastoise    530
# 9     Caterpie    195
# 10     Metapod    205
# 11  Butterfree    395
# 12      Weedle    195
# 13      Kakuna    205
# 14    Beedrill    395
# 15      Pidgey    251
# 16   Pidgeotto    349
# 17     Pidgeot    479
# 18     Rattata    253
# 19    Raticate    413

# %% [markdown]
# ### Filtering Data

# %% [markdown]
# We can also extract data from a `DataFrame` *conditionally* using a Boolean Mask - i.e. an array of boolean values with the same length as the data we're looking to filter. For example, let's say we wanted to extract all of the first-gen Pokemon:

# %%
is_first_gen = pokedex['Generation'] == 1
# Displaying the first and last ten rows so you get the point
print(is_first_gen[:10])
print(is_first_gen[-10:])
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# Name: Generation, dtype: bool
# 1184    False
# 1185    False
# 1186    False
# 1187    False
# 1188    False
# 1189    False
# 1190    False
# 1191    False
# 1192    False
# 1193    False
# Name: Generation, dtype: bool

# %% [markdown]
# Then we feed the mask to the `DataFrame` to *filter* out the unnecessary data. Only the data where the mask has a value of `True` will be kept.

# %%
first_gen = pokedex[is_first_gen]
# sampling 10 pokemon at random to show they're all first gen!
first_gen.sample(10)
# Out:
#       ID       Name Form     Type1   Type2  Total  HP  Attack  Defense
# 86    87    Dewgong          Water     Ice    475  90      70       80  \
# 5      6  Charizard           Fire  Flying    534  78      84       78
# 26    27  Sandshrew         Ground            300  50      75       85
# 137  138    Omanyte           Rock   Water    355  35      40      100
# 100  101  Electrode       Electric            490  60      50       70
# 48    49   Venomoth            Bug  Poison    450  70      65       60
# 144  145     Zapdos       Electric  Flying    580  90      90       85
# 8      9  Blastoise          Water            530  79      83      100
# 23    24      Arbok         Poison            448  60      95       69
# 135  136    Flareon           Fire            525  65     130       60
#
#      Sp. Atk  Sp. Def  Speed  Generation
# 86        70       95     70           1
# 5        109       85    100           1
# 26        20       30     40           1
# 137       90       55     35           1
# 100       80       80    150           1
# 48        90       75     90           1
# 144      125       90    100           1
# 8         85      105     78           1
# 23        65       79     80           1
# 135       95      110     65           1

# %% [markdown]
# We can write even more complex filters by using *multiple* boolean masks and *combining them using a boolean operator*. For example, let's say we wanted to consider all generation 1 Pokemon with `HP` greater than or equal to `100`. We already have the mask for generation 1 Pokemon, so let's create the mask for the `HP`:

# %%
is_beefy = pokedex['HP'] >= 100
# Check to ensure the filter works
pokedex[is_beefy].sample(10)
# Out:
#         ID         Name           Form    Type1   Type2  Total   HP  Attack
# 39      40   Wigglytuff                  Normal   Fairy    435  140      70  \
# 150    151          Mew                 Psychic            600  100     100
# 907    792       Lunala                 Psychic   Ghost    680  137     113
# 1062   897    Spectrier                   Ghost            580  100      65
# 1053   890    Eternatus                  Poison  Dragon    690  140      85
# 1065   898      Calyrex   Shadow Rider  Psychic   Ghost    680  100      85
# 715    382       Kyogre  Primal Kyogre    Water            770  100     150
# 501    487     Giratina  Altered Forme    Ghost  Dragon    680  150     100
# 1186  1003      Ting-Lu                    Dark  Ground    570  155     110
# 1009   851  Centiskorch                    Fire     Bug    525  100     115
#
#       Defense  Sp. Atk  Sp. Def  Speed  Generation
# 39         45       85       50     45           1
# 150       100      100      100    100           1
# 907        89      137      107     97           7
# 1062       60      145       80    130           8
# 1053       95      145       95    130           8
# 1065       80      165      100    150           8
# 715        90      180      160     90           6
# 501       120      100      120     90           4
# 1186      125       55       80     45           9
# 1009       65       90       90     65           8

# %% [markdown]
# Now that we've ensured both filters work, we can combine them using the boolean AND operator. **Note:** It's crucial that when you're working with arrays that you use the *vectorized* AND operator, `&`, and not the default `and`.

# %%
pokedex[is_first_gen & is_beefy]
# Out:
#       ID        Name Form    Type1  Type2  Total   HP  Attack  Defense
# 38    39  Jigglypuff        Normal  Fairy    270  115      45       20  \
# 39    40  Wigglytuff        Normal  Fairy    435  140      70       45
# 88    89         Muk        Poison           500  105     105       75
# 111  112      Rhydon        Ground   Rock    485  105     130      120
# 112  113     Chansey        Normal           450  250       5        5
# 114  115  Kangaskhan        Normal           490  105      95       80
# 130  131      Lapras         Water    Ice    535  130      85       80
# 133  134    Vaporeon         Water           525  130      65       60
# 142  143     Snorlax        Normal           540  160     110       65
# 149  150      Mewtwo       Psychic           680  106     110       90
# 150  151         Mew       Psychic           600  100     100      100
#
#      Sp. Atk  Sp. Def  Speed  Generation
# 38        45       25     20           1
# 39        85       50     45           1
# 88        65      100     50           1
# 111       45       45     40           1
# 112       35      105     50           1
# 114       40       80     90           1
# 130       85       95     60           1
# 133      110       95     65           1
# 142       65      110     30           1
# 149      154       90    130           1
# 150      100      100    100           1

# %% [markdown]
# What if we want to see all electric Pokemon from the dataset? Remember that Pokemon can have *two* types, so we'll need to check both `Type1` and `Type2`. Since we'd like to include a Pokemon if *either* its `Type1` **or** `Type2` is electric, we'll have to use the vectorized boolean OR, the pipe symbol `|`:

# %%
is_electric1 = pokedex['Type1'] == 'Electric'
is_electric2 = pokedex['Type2'] == 'Electric'

pokedex[is_electric1 | is_electric2].sample(10)
# Out:
#        ID          Name            Form     Type1     Type2  Total   HP
# 1171  989  Sandy Shocks                  Electric    Ground    570   85  \
# 613   595        Joltik                       Bug  Electric    319   50
# 818    74       Geodude  Alolan Geodude      Rock  Electric    300   40
# 488   479         Rotom                  Electric     Ghost    440   50
# 1059  894     Regieleki                  Electric              580   80
# 311   312         Minun                  Electric              405   60
# 1038  877       Morpeko     Hangry Mode  Electric      Dark    436   58
# 844   737     Charjabug                       Bug  Electric    400   57
# 1005  848         Toxel                  Electric    Poison    242   40
# 636   618      Stunfisk                    Ground  Electric    471  109
#
#       Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 1171      81       97      121       85    101           9
# 613       47       50       57       50     65           5
# 818       80      100       30       30     20           7
# 488       50       77       95       77     91           4
# 1059     100       50      100       50    200           8
# 311       40       50       75       85     95           3
# 1038      95       58       70       58     97           8
# 844       82       95       55       75     36           7
# 1005      38       35       54       35     40           8
# 636       66       84       81       99     32           5

# %% [markdown]
# ### Practice Questions:

# %% [markdown]
# - How many Pokemon from generation 3 have a `Defense` greater than their `Attack`?

# %%
is_gen3 = pokedex['Generation'] == 3
turtles = pokedex['Defense'] > pokedex['Attack']
len(pokedex[is_gen3 & turtles])
# Out:
# 55

# %% [markdown]
# - How many Steel type Pokemon have a `Total` greater than or equal to 500?

# %%
is_steel1 = pokedex['Type1'] == 'Steel'
is_steel2 = pokedex['Type2'] == 'Steel'
total_gt_500 = pokedex['Total'] >= 500
len(pokedex[(is_steel1 | is_steel2) & total_gt_500])
# Out:
# 42

# %% [markdown]
# - What is the average `Total` across all Generation 1 Pokemon?

# %%
# Mean Total for Generation 1
is_first_gen = pokedex['Generation'] == 1
pokedex[is_first_gen]['Total'].mean()
# Out:
# 407.6423841059603

# %% [markdown]
# - **Power creep** describes the condition where new content added to a multiplayer game eclipses the older content in terms of strength. Using the `Total` column as a rough proxy for overall Pokemon strength, do you see any evidence of power creep across generations in this dataset?

# %%
# Perhaps the best you can do (for now - look ahead to the next section to see the built-in way to do this!)

for i in range(1, 10):
    print(f"Generation {i}:\t {pokedex[pokedex['Generation'] == i]['Total'].mean()}")
# Out:
# Generation 1:	 407.6423841059603
# Generation 2:	 407.18
# Generation 3:	 408.2482269503546
# Generation 4:	 447.89830508474574
# Generation 5:	 434.8969696969697
# Generation 6:	 505.6106870229008
# Generation 7:	 452.89344262295083
# Generation 8:	 460.7959183673469
# Generation 9:	 446.47899159663865

# %% [markdown]
# It looks like there's some evidence of power creep, but it'd be nice to create a visualization! Let's see if we can get this data into a `DataFrame` and plot it.

# %% [markdown]
# ## `.groupby()`: Split, Apply, Combine

# %% [markdown]
# Notice that in the previous example, we effectively did three things to our dataset:
# - **split** the data into categories based on some criteria - in this case, by `Generation`
# - **apply** some transformation or aggregation to the data by group - in this case, we took the mean of each `Total` column.
# - **combine** the transformed data so it can be read and interpreted easily - here we simply printed out the data, but we can just as easily create a *new* `DataFrame`
#
# The [`.groupby()` method of `DataFrame` objects](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html#pandas.DataFrame.groupby) allows us to perform all three of these steps in a single command!

# %%
# Group the Pokemon by Generation and aggregate by taking the mean of the 'Total' column.
# (The double brackets around the column name ensure we get a DataFrame and not a Series as output)
pokedex.groupby(by='Generation')[['Total']].mean()
# Out:
#                  Total
# Generation
# 1           407.642384
# 2           407.180000
# 3           408.248227
# 4           447.898305
# 5           434.896970
# 6           505.610687
# 7           452.893443
# 8           460.795918
# 9           446.478992
